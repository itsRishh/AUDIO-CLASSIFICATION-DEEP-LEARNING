# %% [markdown]
# #omnamahshivay
# hi shivji, our goal is to find patterns, graphs that show a pattern within the data,
# i want you to assist me in this process, and also find patterns for the same. lets do this. sambh sadashiv

# %%
# !pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'D:\Jaansuu\my-env\Scripts\python.exe -m pip install --upgrade pip' command.
# ...
#      -------------------------------------- 294.9/294.9 KB 4.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 11.6/11.6 MB 3.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 346.6/346.6 KB 7.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 508.0/508.0 KB 7.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("../dict_spandan/dict_new_1.csv", encoding='latin-1')

# df = pd.read_csv("C:\\Users\\hp1\\OneDrive\\Desktop\\Tech Atriocare\\Combined_dict.csv", encoding='latin-1')

# %%
df
# Out:
#       Time Frame  Frequency
# 0              0     2050.5
# 1              1     2072.0
# 2              2     2072.0
# 3              3     2072.0
# 4              4     2072.0
# ...          ...        ...
# 1063        1063     2115.0
# 1064        1064     2115.0
# 1065        1065     2115.0
# 1066        1066     2093.5
# 1067        1067     1986.0
#
# [1068 rows x 2 columns]

# %%
df.head()
# Out:
#    Time Frame  Frequency
# 0           0     2050.5
# 1           1     2072.0
# 2           2     2072.0
# 3           3     2072.0
# 4           4     2072.0

# %%
df.shape
# Out:
# (1068, 2)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Time Frame  Frequency
# 0              0     2050.5
# 1              1     2072.0
# 2              2     2072.0
# 3              3     2072.0
# 4              4     2072.0
# ...          ...        ...
# 1063        1063     2115.0
# 1064        1064     2115.0
# 1065        1065     2115.0
# 1066        1066     2093.5
# 1067        1067     1986.0
#
# [1068 rows x 2 columns]>

# %%
df.columns
# Out:
# Index(['Time Frame', 'Frequency'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Time Frame  1068 non-null   int64
#  1   Frequency   1068 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 16.8 KB

# %%
df.describe()
# Out:
#         Time Frame    Frequency
# count  1068.000000  1068.000000
# mean    533.500000  2122.025749
# std     308.449348    26.054599
# min       0.000000  1986.000000
# 25%     266.750000  2115.000000
# 50%     533.500000  2136.500000
# 75%     800.250000  2136.500000
# max    1067.000000  2136.500000

# %% [markdown]
# ## In Data Analysis What all things we do
#
# 1.Missing Values
#
# 2.Explore about the numerical variables.
#
# 3.Explore about Categorical Variables.
#
# 4.Finding Relationship between features.

# %%
df.isnull().sum()
# Out:
# Time Frame    0
# Frequency     0
# dtype: int64

# %% [markdown]
# ## There are no missing values in our data

# %%
import matplotlib.pyplot as plt

# Assume df is your DataFrame and it has 'Time_Frame' as the first column
plt.figure(figsize=(16, 8))

# Iterate over the 18 frequency columns and plot each against Time_Frame
for col in df.columns[1:]:  # Assuming first column is Time_Frame
    plt.plot(df['Time Frame'], df[col], label=col)

# Adding title and labels
plt.title('Frequency Trends Over Time')
plt.xlabel('Time Frame')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')

# Adding legend to show each line represents which frequency column
plt.legend(title='Frequency Columns', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example data (replace with your actual data)
data = pd.DataFrame({
    'time_frame': range(1000),
    'freq_1': np.random.uniform(1950, 2250, 1000),
    'freq_p3_1': np.random.uniform(1950, 2250, 1000),
    # Add other frequency columns as needed
})

print(data['freq_1'])

# Plot
plt.figure(figsize=(12, 6))

# Plot only a subset of data to reduce clutter
for col in data.columns[1:6]:  # Adjust the range as needed
    plt.plot(data['time_frame'], data[col], label=col)

plt.title("Frequency Trends Over Time")
plt.xlabel("Time Frame")
plt.ylabel("Frequency")
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))  # Move legend outside
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)  # Lighter grid lines
plt.tight_layout()  # Adjust layout to fit everything

plt.show()
# Out:
# 0      2077.614109
# 1      2249.693525
# 2      2030.125663
# 3      2241.363913
# 4      2201.705518
#           ...
# 995    1955.004585
# 996    2227.469660
# 997    2148.829266
# 998    2013.016295
# 999    2223.436563
# Name: freq_1, Length: 1000, dtype: float64

# %%
import seaborn as sns

# Assuming the DataFrame is structured with 'Time_Frame' as the index
df_melted = df.melt(id_vars=['Time Frame'], var_name='Frequency_Column', value_name='Frequency_value')

plt.figure(figsize=(14, 8))

# Creating the heatmap
sns.heatmap(df.iloc[:, 1:].T, cmap='viridis', cbar=True)

# Adjusting the plot
plt.title('Heatmap of Frequencies Across Time Frames')
plt.xlabel('Time Frame')
plt.ylabel('Frequency Columns')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## What This Code Does:
# ## It creates a heatmap to show the distribution of frequency values across different time frames and frequency columns.
#
# ## The color intensity indicates the magnitude of the frequency values at specific time frames. Darker colors typically represent higher values, and lighter colors represent lower values.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame with 'Time_Frame' as a column

# Step 1: Verify column names in the DataFrame
print("Available columns in DataFrame:", df.columns)

# Step 2: Adjust the column names according to the actual DataFrame
# Change this list to reflect the correct column names in your DataFrame
selected_columns = ['freq_1', 'freq_p3_1', 'freq_p4_1', 'freq_p5_1', 'freq_p9_1']

# Check if selected columns are in DataFrame
selected_columns = [col for col in selected_columns if col in df.columns]
if not selected_columns:
    raise ValueError("None of the selected columns are present in the DataFrame.")

filtered_df = df[selected_columns]


# Step 3: Resample/Aggregate data if 'Time_Frame' is present and meaningful
# Here we simulate aggregation for simplicity
aggregated_df = filtered_df.groupby(filtered_df.index // 50).mean()  # Adjust the divisor for resampling

# Step 4: Prepare for heatmap plotting
plt.figure(figsize=(18, 10))  # Increase figure size for clarity

# Step 5: Create the heatmap with clustering and custom color map
sns.heatmap(aggregated_df.T, cmap='viridis', cbar=True, linewidths=0.5, linecolor='gray', 
            vmin=1950, vmax=2250)  # Adjust vmin/vmax based on your data range

# Step 6: Customize the labels and layout
plt.title('Heatmap of Frequencies Across Time Frames')
plt.xlabel('Time Frame')
plt.ylabel('Frequency Columns')
plt.xticks(rotation=45, fontsize=10)  # Rotate x-axis labels for readability
plt.yticks(fontsize=10)  # Set y-axis font size

plt.tight_layout()  # Adjust layout for better fit
plt.show()
# Out:
# Available columns in DataFrame: Index(['Time Frame', 'Frequency'], dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 18
#      16 selected_columns = [col for col in selected_columns if col in df.columns]
#      17 if not selected_columns:
# ---> 18     raise ValueError("None of the selected columns are present in the DataFrame.")
#      20 filtered_df = df[selected_columns]
#      22 print(df.columns)
#
# ValueError: None of the selected columns are present in the DataFrame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame with 'Time_Frame' as a column

# Step 1: Verify column names in the DataFrame
print("Available columns in DataFrame:", df.columns)

# Step 2: Adjust the column names according to the actual DataFrame
# Change this list to reflect the correct column names in your DataFrame
selected_columns = ['Time Frame', 'Frequency']

# Check if selected columns are in DataFrame
selected_columns = [col for col in selected_columns if col in df.columns]
if not selected_columns:
    raise ValueError("None of the selected columns are present in the DataFrame.")

filtered_df = df[selected_columns]

# Step 3: Resample/Aggregate data if 'Time_Frame' is present and meaningful
# Here we simulate aggregation for simplicity
aggregated_df = filtered_df.groupby(filtered_df.index // 50).mean()  # Adjust the divisor for resampling

# Step 4: Prepare for heatmap plotting
plt.figure(figsize=(18, 10))  # Increase figure size for clarity

# Step 5: Create the heatmap with clustering and custom color map
sns.heatmap(aggregated_df.T, cmap='viridis', cbar=True, linewidths=0.5, linecolor='gray', 
            vmin=1950, vmax=2250)  # Adjust vmin/vmax based on your data range

# Step 6: Customize the labels and layout
plt.title('Heatmap of Frequencies Across Time Frames')
plt.xlabel('Time Frame')
plt.ylabel('Frequency Columns')
plt.xticks(rotation=45, fontsize=10)  # Rotate x-axis labels for readability
plt.yticks(fontsize=10)  # Set y-axis font size

plt.tight_layout()  # Adjust layout for better fit
plt.show()
# Out:
# Available columns in DataFrame: Index(['Time Frame', 'Frequency'], dtype='object')

# %% [markdown]
# ## The freq_p9_1 column stands out due to its consistently higher frequency values, while freq_p5_1 tends to have lower values.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the plotting style
sns.set(style="whitegrid")

# Plotting Time Series of Frequency over Time Frame
plt.figure(figsize=(14, 6))
sns.lineplot(x='Time Frame', y='Frequency', data=df, marker='o')
plt.title('Frequency Over Time Frame')
plt.xlabel('Time_Frame')
plt.ylabel('freq_1 freq')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Summary of Insights:
# The scatter plot shows a predominant frequency range (between 2080 and 2140), suggesting stable conditions.
# Occasional drops in frequency values could indicate anomalies or disturbances in the system.
# The clustering of data points suggests a high sampling rate or precision, capturing fine details of the frequency changes.

# %%
#Plotting the Distribution of Frequency

plt.figure(figsize=(10, 6))
sns.histplot(df['freq_p3_1'], kde=True, bins=30, color='skyblue')
plt.title('Distribution of Frequency')
plt.xlabel('freq_p3_1')
plt.ylabel('Count')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Jaansuu\my-env\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'freq_p3_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 4
#       1 #Plotting the Distribution of Frequency
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['freq_p3_1'], kde=True, bins=30, color='skyblue')
plt.title('Distribution of Frequency')
plt.xlabel('freq_p3_1')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
##correlation matrix.

import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr_matrix = df.iloc[:, 1:].corr()  # Excluding 'Time Frame' column

# Plotting the correlation matrix using a heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix of Frequency Columns')
plt.show()

# %%
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot

# Assuming 'df' is your DataFrame and contains all the frequency columns
# List of all frequency columns (excluding 'Time Frame')
frequency_columns = [
    'freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 'freq_p5_1', 'freq_p5_2',
    'freq_p6_1', 'freq_p7_1', 'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1',
    'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1', 'freq_p15_1', 'freq_p18_1'
]

# Plot autocorrelation for each frequency column
for col in frequency_columns:
    plt.figure(figsize=(12, 6))
    autocorrelation_plot(df[col])
    plt.title(f'Autocorrelation of {col}')
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot

# Assuming df is your DataFrame with all frequency columns
frequency_columns = [
    'freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 'freq_p5_1', 'freq_p5_2',
    'freq_p6_1', 'freq_p7_1', 'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1',
    'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1', 'freq_p15_1', 'freq_p18_1'
]

# Creating subplots
plt.figure(figsize=(20, 20))
for i, col in enumerate(frequency_columns, 1):
    plt.subplot(6, 3, i)
    autocorrelation_plot(df[col])
    plt.title(f'Autocorrelation of {col}')
    plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1. Y-axis (Autocorrelation): This shows how much the time series data is correlated with its own previous values at different time lags.
# The values range from -1 to 1.
#
# A value close to 1 means strong positive correlation (the data points are similar).
# A value close to -1 means strong negative correlation (the data points are opposite).
# A value close to 0 means no correlation (random relationship).
#
# ## X-axis (Lag): This represents the time lag.
# A lag of 1 means the correlation between each data point and the one immediately before it, a lag of 2 means the correlation with the data point two steps before, and so on.

# %%
# Importing necessary libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data into a DataFrame
# Assuming your DataFrame is named 'df' with frequency columns

# Selecting only the frequency columns for clustering
frequency_columns = ['freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 'freq_p5_1', 'freq_p5_2', 
                     'freq_p6_1', 'freq_p7_1', 'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1', 
                     'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1', 'freq_p15_1', 'freq_p18_1']
frequency_data = df[frequency_columns]

# Step 1: Standardizing the Data
scaler = StandardScaler()
frequency_scaled = scaler.fit_transform(frequency_data)

# Step 2: Determine optimal number of clusters using Elbow Method
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(frequency_scaled)
    sse.append(kmeans.inertia_)

# Plotting the Elbow Curve
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), sse, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('Elbow Method For Optimal K')
plt.grid(True)
plt.show()

# Step 3: Applying KMeans Clustering
# Choose an optimal number of clusters (e.g., 3) from the elbow plot
optimal_k = 3  # Example: You should choose based on the Elbow plot
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(frequency_scaled)

# Adding the cluster labels to the original DataFrame
df['Cluster'] = clusters

# Visualizing the clusters
plt.figure(figsize=(12, 8))
sns.scatterplot(x='freq_p3_1', y='freq_p4_1', hue='Cluster', data=df, palette='Set1')
plt.title('K-means Clustering of Frequency Data')
plt.xlabel('freq_p3_1')
plt.ylabel('freq_p4_1')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# Optional: Save or review the clustered data
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Importing necessary libraries
#       2 import pandas as pd
# ----> 3 from sklearn.preprocessing import StandardScaler
#       4 from sklearn.cluster import KMeans
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Importing necessary libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Load the DataFrame (assuming it's named 'df')
# Selecting only the frequency columns for clustering
frequency_columns = ['freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 'freq_p5_1', 
                     'freq_p5_2', 'freq_p6_1', 'freq_p7_1', 'freq_p7_2', 'freq_p8_1', 
                     'freq_p8_2', 'freq_p9_1', 'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 
                     'freq_p14_1', 'freq_p15_1', 'freq_p18_1']

# Step 1: Iterate over each frequency column to apply clustering
for column in frequency_columns:
    
    # Step 2: Standardize the column data
    scaler = StandardScaler()
    frequency_data = df[[column]]
    frequency_scaled = scaler.fit_transform(frequency_data)
    
    # Step 3: Determine optimal number of clusters using Elbow Method for the column
    sse = []
    for k in range(1, 11):
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(frequency_scaled)
        sse.append(kmeans.inertia_)
    
    # Plotting the Elbow Curve for each column
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, 11), sse, marker='o')
    plt.xlabel('Number of Clusters')
    plt.ylabel('SSE (Sum of Squared Errors)')
    plt.title(f'Elbow Method For Optimal K - {column}')
    plt.grid(True)
    plt.show()
    
    # Step 4: Apply KMeans Clustering using optimal number of clusters (choose from the elbow plot)
    # Let's assume 3 clusters for simplicity; adjust based on the elbow plot for each column
    optimal_k = 3
    kmeans = KMeans(n_clusters=optimal_k, random_state=42)
    clusters = kmeans.fit_predict(frequency_scaled)
    
    # Step 5: Add the cluster labels to the original DataFrame
    df[f'{column}_Cluster'] = clusters

    # Step 6: Visualize the clusters using histograms
    plt.figure(figsize=(12, 6))
    sns.histplot(df, x=column, hue=f'{column}_Cluster', kde=True, palette='Set1')
    plt.title(f'Clustering of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.legend(title='Cluster')
    plt.grid(True)
    plt.show()

# Review the updated DataFrame with cluster labels
df.head()

# %%
# Importing necessary libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Selecting only the frequency columns for clustering
frequency_columns = ['freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 'freq_p5_1', 
                     'freq_p5_2', 'freq_p6_1', 'freq_p7_1', 'freq_p7_2', 'freq_p8_1', 
                     'freq_p8_2', 'freq_p9_1', 'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 
                     'freq_p14_1', 'freq_p15_1', 'freq_p18_1']

# Step 1: Standardize the data
scaler = StandardScaler()
frequency_data = df[frequency_columns]
frequency_scaled = scaler.fit_transform(frequency_data)

# Step 2: Determine optimal number of clusters using Elbow Method
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(frequency_scaled)
    sse.append(kmeans.inertia_)

# Plotting the Elbow Curve to find optimal K
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), sse, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('Elbow Method For Optimal K')
plt.grid(True)
plt.show()

# Step 3: Apply KMeans Clustering using optimal number of clusters
# Assuming 3 clusters as optimal for demonstration; adjust based on the elbow plot
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(frequency_scaled)

# Step 4: Add the cluster labels to the original DataFrame
df['Cluster'] = clusters

# Step 5: Visualizing clusters using a pair plot or heatmap
# Pairplot is great if we want to see relationships, but heatmap can show aggregate clustering patterns

# Visualize using Pairplot
sns.pairplot(df, hue='Cluster', vars=frequency_columns, palette='Set1', diag_kind='kde')
plt.suptitle('Pairplot of Clusters Across All Frequency Columns', y=1.02)
plt.show()

# Alternative: Visualize using a Heatmap (mean values per cluster)
# Compute the mean of each frequency column per cluster
cluster_means = df.groupby('Cluster')[frequency_columns].mean()

plt.figure(figsize=(15, 8))
sns.heatmap(cluster_means, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Cluster Means for Frequency Columns')
plt.xlabel('Frequency Columns')
plt.ylabel('Cluster')
plt.show()

# %%
import pywt

# Select a column for wavelet transform, let's choose 'freq_1' as an example
data = df['freq_1 freq']

# Perform Continuous Wavelet Transform (CWT)
scales = np.arange(1, 128)
coefficients, frequencies = pywt.cwt(data, scales, 'cmor')

# Plot the scalogram
plt.figure(figsize=(10, 6))
plt.imshow(np.abs(coefficients), extent=[0, len(data), scales[-1], scales[0]], cmap='jet', aspect='auto')
plt.colorbar(label='Magnitude')
plt.xlabel('Time')
plt.ylabel('Scale')
plt.title('Wavelet Transform (Scalogram) of freq_1')
plt.show()

# %%
# Define the frequency columns (assuming they are named similarly)
frequency_columns = [
    'freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 
    'freq_p5_1', 'freq_p5_2', 'freq_p6_1', 'freq_p7_1',
    'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1',
    'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1',
    'freq_p15_1', 'freq_p18_1'
]

# Perform wavelet transform and plot for each frequency column
for column in frequency_columns:
    data = df[column]

    # Perform Continuous Wavelet Transform (CWT)
    scales = np.arange(1, 128)
    coefficients, frequencies = pywt.cwt(data, scales, 'cmor')

    # Plot the scalogram
    plt.figure(figsize=(10, 6))
    plt.imshow(np.abs(coefficients), extent=[0, len(data), scales[-1], scales[0]], cmap='jet', aspect='auto')
    plt.colorbar(label='Magnitude')
    plt.xlabel('Time')
    plt.ylabel('Scale')
    plt.title(f'Wavelet Transform (Scalogram) of {column}')
    plt.show()

# %%
# Choose two frequency columns for cross-correlation
col1 = 'freq_1 freq'
col2 = 'freq_p3_1'

# Compute cross-correlation
cross_corr = np.correlate(df[col1] - np.mean(df[col1]), df[col2] - np.mean(df[col2]), mode='full')

# Generate the lags array
lags = np.arange(-len(df[col1]) + 1, len(df[col1]))

# Plot the cross-correlation
plt.figure(figsize=(10, 6))
plt.plot(lags, cross_corr)
plt.xlabel('Lag')
plt.ylabel('Cross-correlation')
plt.title(f'Cross-Correlation between {col1} and {col2}')
plt.grid(True)
plt.show()

# %%
# Define the frequency columns
frequency_columns = [
    'freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 
    'freq_p5_1', 'freq_p5_2', 'freq_p6_1', 'freq_p7_1',
    'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1',
    'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1',
    'freq_p15_1', 'freq_p18_1'
]

# Initialize an empty DataFrame to store cross-correlation coefficients
cross_corr_matrix = pd.DataFrame(index=frequency_columns, columns=frequency_columns)

# Compute cross-correlation for each pair of columns
for col1 in frequency_columns:
    for col2 in frequency_columns:
        if col1 != col2:
            # Compute cross-correlation and find the maximum value
            cross_corr = np.correlate(df[col1] - np.mean(df[col1]), df[col2] - np.mean(df[col2]), mode='full')
            max_corr = np.max(np.abs(cross_corr)) / (np.std(df[col1]) * np.std(df[col2]) * len(df[col1]))
            cross_corr_matrix.loc[col1, col2] = max_corr
        else:
            cross_corr_matrix.loc[col1, col2] = 1  # Correlation with itself

# Convert the matrix values to float for plotting
cross_corr_matrix = cross_corr_matrix.astype(float)

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(cross_corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f')
plt.title('Cross-Correlation Matrix of Frequency Columns')
plt.show()

# %% [markdown]
# ## Cross-Correlation Matrix: The cross_corr_matrix DataFrame stores the maximum cross-correlation values between each pair of frequency columns.
# Heatmap: The heatmap is a visual representation where each cell's color intensity reflects the strength of the cross-correlation between two columns.
# Diagonal Values: The diagonal of the matrix represents the correlation of each frequency with itself, which is always 1.
# Insights:
# High Cross-Correlation: Darker or more intense colors indicate a higher cross-correlation between two frequency columns, suggesting that these two signals have a strong relationship.
# Low Cross-Correlation: Lighter colors indicate weaker or no significant relationship between the two signals.
# Customization:
# Lag Analysis: If you're interested in specific lags, you can modify the code to store the cross-correlation values for those particular lags.
# Thresholding: You can filter the matrix to show only cross-correlations above a certain threshold if you are interested in significant correlations only.

# %%
pip install tslearn

# %%
from tslearn.clustering import KShape

# Define the frequency columns
frequency_columns = [
    'freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 
    'freq_p5_1', 'freq_p5_2', 'freq_p6_1', 'freq_p7_1',
    'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1',
    'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1',
    'freq_p15_1', 'freq_p18_1'
]

# Prepare data for clustering
# Convert the dataframe to numpy array
X = df[frequency_columns].values

# Reshape the data to be 3D: (n_samples, n_timestamps, 1)
X_reshaped = X.reshape((X.shape[0], X.shape[1], 1))

# Perform K-Shape clustering
n_clusters = 3  # Specify the number of clusters you want
kshape = KShape(n_clusters=n_clusters, random_state=0)
y_pred = kshape.fit_predict(X_reshaped)

# Visualize the clusters
plt.figure(figsize=(12, 8))
for cluster in range(n_clusters):
    plt.subplot(n_clusters, 1, cluster + 1)
    for i in range(len(X_reshaped)):
        if y_pred[i] == cluster:
            plt.plot(X_reshaped[i].flatten(), "k-", alpha=.2)
    plt.plot(kshape.cluster_centers_[cluster].flatten(), "r-")
    plt.title(f'Cluster {cluster + 1}')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.cluster import KMeans

# Load the CSV file into a pandas DataFrame
file_path = 'C:\\Users\\hp1\\OneDrive\\Desktop\\Tech Atriocare\\Combined_dict.csv'  # Replace with the actual file path
df = pd.read_csv(file_path)

# Display the first few rows of the dataframe to understand its structure
print(df.head())

# Check basic statistics
print(df.describe())

# Plotting frequency columns over time
time_frame = df['Time_Frame']  # Adjust this if your time column has a different name
frequency_columns = df.columns[1:]  # Assuming frequency columns start from the second column

# Plotting frequency distribution
plt.figure(figsize=(12, 6))
for column in frequency_columns:
    sns.lineplot(x=time_frame, y=df[column], label=column)
plt.xlabel('Time Frame')
plt.ylabel('Frequency')
plt.title('Frequency Distribution Over Time')
plt.legend(title='Frequency Columns')
plt.show()

# Detecting anomalies using Z-score
anomalies = pd.DataFrame()
threshold = 3  # Z-score threshold for anomalies
for column in frequency_columns:
    z_scores = stats.zscore(df[column])
    anomaly_indices = list(df.index[abs(z_scores) > threshold])
    anomalies[column] = df[column][anomaly_indices]
    
# Print the detected anomalies
print("Anomalies detected:")
print(anomalies)

# Optional: Plot anomalies if detected
for column in frequency_columns:
    plt.figure(figsize=(12, 6))
    sns.lineplot(x=time_frame, y=df[column], label=f"Frequency {column}")
    plt.scatter(df.index[anomalies[column].dropna().index], anomalies[column].dropna(), color='red', label='Anomalies')
    plt.xlabel('Time_Frame')
    plt.ylabel('Frequency')
    plt.title(f'Anomalies in Frequency Column: {column}')
    plt.legend()
    plt.show()

# Clustering to find patterns
num_clusters = 3  # You can change the number of clusters
kmeans = KMeans(n_clusters=num_clusters)

# Fit the model
kmeans.fit(df[frequency_columns])

# Add cluster labels to the original dataframe
df['Cluster'] = kmeans.labels_

# Visualizing clusters
plt.figure(figsize=(12, 6))
sns.scatterplot(x=df[frequency_columns[0]], y=df[frequency_columns[1]], hue=df['Cluster'], palette='viridis')
plt.title('Clustering of Frequency Data')
plt.xlabel(f'Frequency: {frequency_columns[0]}')
plt.ylabel(f'Frequency: {frequency_columns[1]}')
plt.legend(title='Cluster')
plt.show()

# %%
# %pylab inline

import numpy as np
from matplotlib import pyplot as plt

def decision_boundary(x_1):
    """ Calculates the x_2 value for plotting the decision boundary."""
    return 4 - np.sqrt(-x_1**2 + 4*x_1 + 6 + np.log(16))

def decision_rule(x_vec)
x_1^2 + x_2^2 - -4x_1 - 8x_2 - 4ln(2) + 10 = 0


# Generate 100 random patterns for class1
mu_vec1 = np.array([0,0])
cov_mat1 = np.array([[2,0],[0,2]])
x1_samples = np.random.multivariate_normal(mu_vec1, cov_mat1, 100)
mu_vec1 = mu_vec1.reshape(1,2).T # to 1-col vector

# Generate 100 random patterns for class2
mu_vec2 = np.array([1,2])
cov_mat2 = np.array([[1,0],[0,1]])
x2_samples = np.random.multivariate_normal(mu_vec2, cov_mat2, 100)
mu_vec2 = mu_vec2.reshape(1,2).T # to 1-col vector

# Scatter plot
f, ax = plt.subplots(figsize=(7, 7))
ax.scatter(x1_samples[:,0], x1_samples[:,1], marker='o', color='green', s=40, alpha=0.5)
ax.scatter(x2_samples[:,0], x2_samples[:,1], marker='^', color='blue', s=40, alpha=0.5)
plt.legend(['Class1 (w1)', 'Class2 (w2)'], loc='upper right') 
plt.title('Densities of 2 classes with 100 bivariate random patterns each')
plt.ylabel('x2')
plt.xlabel('x1')
ftext = 'p(x|w1) ~ N(mu1=(0,0)^t, cov1=2*I)\np(x|w2) ~ N(mu2=(1,2)^t, cov2=I)'
plt.figtext(.15,.8, ftext, fontsize=11, ha='left')

# Plot decision boundary
x_1 = np.arange(-5, 5, 0.1)
bound = decision_boundary(x_1)
plt.plot(x_1, bound, 'r--', lw=4)

x_vec = np.linspace(*ax.get_xlim())
x_1 = np.arange(0, 100, 0.05)

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Assuming df is your DataFrame with frequency columns
# Extract only the frequency columns
frequency_columns = [
    'freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 'freq_p5_1', 'freq_p5_2',
    'freq_p6_1', 'freq_p7_1', 'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1',
    'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1', 'freq_p15_1', 'freq_p18_1'
]

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[frequency_columns])

# Apply PCA to reduce to 2 dimensions
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

# Apply KMeans Clustering
kmeans = KMeans(n_clusters=3, random_state=42)  # Adjust number of clusters as needed
clusters = kmeans.fit_predict(scaled_data)

# Plotting the PCA results and clusters
plt.figure(figsize=(10, 7))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=clusters, cmap='viridis', alpha=0.6, edgecolor='k')
plt.title('Clustering of Frequency Columns after PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster Label')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with frequency columns
# Extract only the frequency columns
frequency_columns = [
    'freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 'freq_p5_1', 'freq_p5_2',
    'freq_p6_1', 'freq_p7_1', 'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1',
    'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1', 'freq_p15_1', 'freq_p18_1'
]

# Define your target variable (assuming 'target' column exists in your DataFrame)
# If you don't have a target, you can generate a synthetic one for demonstration
# For example, let's create a synthetic binary target for demonstration purposes
df['target'] = (df['freq_1 freq'] > df['freq_1 freq'].mean()).astype(int)

# Split the data into training and testing sets
X = df[frequency_columns]
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# Predict on the test set
y_pred = clf.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

# Visualize the Decision Tree
plt.figure(figsize=(20, 10))
plot_tree(clf, feature_names=frequency_columns, class_names=['Class 0', 'Class 1'], filled=True)
plt.title("Decision Tree on Frequency Columns")
plt.show()

# %% [markdown]
# This decision tree visualization provides insights into how your frequency columns are being used to classify data into different classes (Class 0 and Class 1). Here's a breakdown of the key information from the decision tree plot:
#
#
# Root Node (Top Node):
#
# Feature Used: freq_p7_1
# Threshold: The decision point is set at <= 2125.75. This means the data is split based on whether the value of freq_p7_1 is less than or equal to 2125.75.
# Gini Index: 0.477 — The Gini index measures the impurity or variability in the data. A Gini index of 0 would mean perfect classification. Here, a value of 0.477 indicates moderate impurity.
# Samples: 747 — This represents the total number of data points considered at this node.
# Value: [293, 454] — This indicates the distribution of the samples between the two classes: 293 samples belong to Class 0 and 454 to Class 1.
# Class: Class 1 — Since Class 1 has more samples (454), this node is classified as Class 1.
# Left Child Node (Orange Node):
#
# Condition: This node represents the subset where freq_p7_1 is <= 2125.75.
# Gini Index: 0.0 — A Gini index of 0 indicates perfect separation, meaning all samples in this node belong to a single class.
# Samples: 293 — All 293 samples belong to Class 0.
# Value: [293, 0] — Indicates that all samples are in Class 0.
# Class: Class 0 — Since all samples are of Class 0, this node is classified as Class 0.
# Right Child Node (Blue Node):
#
# Condition: This node represents the subset where freq_p7_1 is > 2125.75.
# Gini Index: 0.0 — Again, a Gini index of 0 indicates that all samples are perfectly classified into a single class.
# Samples: 454 — All 454 samples belong to Class 1.
# Value: [0, 454] — Indicates that all samples are in Class 1.
# Class: Class 1 — Since all samples are of Class 1, this node is classified as Class 1.
# Summary:
#
# The decision tree uses freq_p7_1 as the key feature to split the data.
# If freq_p7_1 is less than or equal to 2125.75, the samples are classified as Class 0.
# If freq_p7_1 is greater than 2125.75, the samples are classified as Class 1.
# The Gini index of 0 in the child nodes indicates perfect classification with no impurity, meaning the decision boundary defined by freq_p7_1 is highly effective for this split.
# This decision tree shows that freq_p7_1 is a strong predictor for distinguishing between Class 0 and Class 1 based on the given threshold, resulting in clear and distinct classifications at each split.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Example on 'freq_1 freq' - Replace with appropriate column names
column_name = 'freq_1 freq'  # Update as per your data

# Ensure your data is indexed by time
df['Date'] = pd.to_datetime(df['Date'])  # Assuming there's a Date column
df.set_index('Date', inplace=True)

# Plot the data
plt.figure(figsize=(10, 5))
plt.plot(df[column_name])
plt.title(f'Time Series Plot of {column_name}')
plt.show()

# Check for stationarity
from statsmodels.tsa.stattools import adfuller

result = adfuller(df[column_name].dropna())
print('ADF Statistic:', result[0])
print('p-value:', result[1])

# If not stationary, consider differencing
df_diff = df[column_name].diff().dropna()

# Use Auto ARIMA to find best (p, d, q)
auto_arima_model = auto_arima(df[column_name], 
                              start_p=1, start_q=1,
                              max_p=3, max_q=3, m=1,
                              seasonal=False,
                              trace=True,
                              error_action='ignore',  
                              suppress_warnings=True, 
                              stepwise=True)

print(auto_arima_model.summary())

# Fit ARIMA model
model = ARIMA(df[column_name], order=auto_arima_model.order)
model_fit = model.fit()

# Summary of the model
print(model_fit.summary())

# Forecasting
forecast = model_fit.forecast(steps=10)
plt.figure(figsize=(10, 5))
plt.plot(df[column_name], label='Historical Data')
plt.plot(pd.date_range(df.index[-1], periods=10, freq='D'), forecast, label='Forecast')
plt.title(f'Forecast for {column_name}')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# Load your data here
# Assuming 'df' is your dataframe with frequency columns and a 'Date' index
column_name = 'freq_1 freq'  # Replace with the actual column name

# Plot the data
plt.figure(figsize=(10, 5))
plt.plot(df[column_name])
plt.title(f'Time Series Plot of {column_name}')
plt.xlabel('Time_Frame')
plt.ylabel(column_name)
plt.show()

# Check for stationarity using ADF test
result = adfuller(df[column_name].dropna())
print('ADF Statistic:', result[0])
print('p-value:', result[1])

# Differencing if data is not stationary
df_diff = df[column_name].diff().dropna()

# Plot ACF and PACF
plt.figure(figsize=(14, 6))
plt.subplot(121)
plot_acf(df_diff, ax=plt.gca(), lags=20)
plt.title('ACF Plot')
plt.subplot(122)
plot_pacf(df_diff, ax=plt.gca(), lags=20)
plt.title('PACF Plot')
plt.show()

# Fit ARIMA Model - adjust (p, d, q) based on ACF/PACF plots
p = 1  # number of lag observations
d = 1  # differencing needed
q = 1  # size of moving average window

model = ARIMA(df[column_name], order=(p, d, q))
model_fit = model.fit()

# Summary of the model
print(model_fit.summary())

# Forecasting
forecast = model_fit.forecast(steps=10)
plt.figure(figsize=(10, 5))
plt.plot(df[column_name], label='Historical Data')
plt.plot(pd.date_range(df.index[-1], periods=10, freq='D'), forecast, label='Forecast')
plt.title(f'Forecast for {column_name}')
plt.xlabel('Time')
plt.ylabel(column_name)
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# Load your data here
# Assuming 'df' is your dataframe with frequency columns and a 'Date' index
frequency_columns = [col for col in df.columns if 'freq' in col]  # Assuming all columns with 'freq' in name are frequency columns

# Iterate over each frequency column to perform ARIMA analysis
for column_name in frequency_columns:
    print(f"\nAnalyzing column: {column_name}")
    
    # Plot the time series data
    plt.figure(figsize=(10, 5))
    plt.plot(df[column_name])
    plt.title(f'Time Series Plot of {column_name}')
    plt.xlabel('Time')
    plt.ylabel(column_name)
    plt.show()

    # Check for stationarity using ADF test
    result = adfuller(df[column_name].dropna())
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])

    # Differencing if data is not stationary
    if result[1] > 0.05:
        df_diff = df[column_name].diff().dropna()
        d = 1
    else:
        df_diff = df[column_name]
        d = 0

    # Plot ACF and PACF to determine p and q
    plt.figure(figsize=(14, 6))
    plt.subplot(121)
    plot_acf(df_diff, ax=plt.gca(), lags=20)
    plt.title('ACF Plot')
    plt.subplot(122)
    plot_pacf(df_diff, ax=plt.gca(), lags=20)
    plt.title('PACF Plot')
    plt.show()

    # Based on ACF/PACF plots, select (p, d, q) - here we use (1, 1, 1) as default, adjust as needed
    p = 1  # number of lag observations
    q = 1  # size of moving average window

    # Fit ARIMA model
    model = ARIMA(df[column_name], order=(p, d, q))
    model_fit = model.fit()

    # Summary of the model
    print(model_fit.summary())

    # Forecasting future values
    steps = 10  # Number of future steps to forecast
    forecast = model_fit.forecast(steps=steps)
    plt.figure(figsize=(10, 5))
    plt.plot(df[column_name], label='Historical Data')
    plt.plot(pd.date_range(df.index[-1], periods=steps, freq='D'), forecast, label='Forecast')
    plt.title(f'Forecast for {column_name}')
    plt.xlabel('Time')
    plt.ylabel(column_name)
    plt.legend()
    plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller

# Load your data here
# Assuming 'df' is your dataframe with frequency columns and a 'Date' index
frequency_columns = [col for col in df.columns if 'freq' in col]  # Assuming all columns with 'freq' in name are frequency columns

plt.figure(figsize=(15, 8))  # Initialize the plot for all columns

for column_name in frequency_columns:
    print(f"Analyzing column: {column_name}")
    
    # Check for stationarity using ADF test
    result = adfuller(df[column_name].dropna())
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])

    # Differencing if data is not stationary
    if result[1] > 0.05:
        df_diff = df[column_name].diff().dropna()
        d = 1
    else:
        df_diff = df[column_name]
        d = 0

    # Default ARIMA parameters (1, 1, 1); adjust as needed based on your observations from ACF/PACF
    p, q = 1, 1

    # Fit ARIMA model
    model = ARIMA(df[column_name], order=(p, d, q))
    model_fit = model.fit()

    # Forecasting future values
    steps = 10  # Number of future steps to forecast
    forecast = model_fit.forecast(steps=steps)
    
    # Plotting historical data and forecasts
    plt.plot(df[column_name], label=f'{column_name} - Historical')
    plt.plot(pd.date_range(df.index[-1], periods=steps, freq='D'), forecast, linestyle='--', label=f'{column_name} - Forecast')

plt.title('Forecast for Frequency Columns')
plt.xlabel('Time')
plt.ylabel('Frequency Values')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
# !pip install fastdtw scipy

# %%
import numpy as np
from fastdtw import fastdtw
from scipy.spatial.distance import euclidean
import matplotlib.pyplot as plt

# Example data: Two time series
# Replace these with your actual time series data
time_series_1 = np.array([1, 2, 3, 4, 2, 3, 4, 5, 3, 2, 1])
time_series_2 = np.array([2, 3, 4, 3, 4, 5, 4, 3, 2, 1, 2])

# Compute DTW distance between the two time series
distance, path = fastdtw(time_series_1, time_series_2, dist=euclidean)

print(f'DTW Distance: {distance}')
print(f'Optimal Path: {path}')

# Visualize the alignment
plt.figure(figsize=(10, 6))
plt.plot(time_series_1, label='Time Series 1', color='blue')
plt.plot(time_series_2, label='Time Series 2', color='red')

# Add lines to indicate the alignment path
for (i, j) in path:
    plt.plot([i, j], [time_series_1[i], time_series_2[j]], color='gray', linestyle='--')

plt.title('Dynamic Time Warping Alignment')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
from fastdtw import fastdtw
from scipy.spatial.distance import euclidean
import matplotlib.pyplot as plt

# Your specified frequency columns
frequency_columns = [
    'freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 
    'freq_p5_1', 'freq_p5_2', 'freq_p6_1', 'freq_p7_1',
    'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1',
    'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1',
    'freq_p15_1', 'freq_p18_1'
]

# Initialize a dictionary to store DTW distances
dtw_distances = {}

# Calculate DTW distances between all pairs of frequency columns
for i in range(len(frequency_columns)):
    for j in range(i + 1, len(frequency_columns)):
        ts1 = df[frequency_columns[i]].dropna().values
        ts2 = df[frequency_columns[j]].dropna().values

        distance, path = fastdtw(ts1, ts2, dist=euclidean)
        dtw_distances[(frequency_columns[i], frequency_columns[j])] = distance

        print(f'DTW Distance between {frequency_columns[i]} and {frequency_columns[j]}: {distance}')

# Visualize the alignment between the first pair of frequency columns as an example
first_pair = list(dtw_distances.keys())[0]
ts1 = df[first_pair[0]].dropna().values
ts2 = df[first_pair[1]].dropna().values
_, path = fastdtw(ts1, ts2, dist=euclidean)

plt.figure(figsize=(10, 6))
plt.plot(ts1, label=first_pair[0], color='blue')
plt.plot(ts2, label=first_pair[1], color='red')

# Add lines to indicate the alignment path
for (i, j) in path:
    plt.plot([i, j], [ts1[i], ts2[j]], color='gray', linestyle='--')

plt.title(f'Dynamic Time Warping Alignment: {first_pair[0]} vs {first_pair[1]}')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
from fastdtw import fastdtw
from scipy.spatial.distance import euclidean
import matplotlib.pyplot as plt

# Your specified frequency columns
frequency_columns = [
    'freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 
    'freq_p5_1', 'freq_p5_2', 'freq_p6_1', 'freq_p7_1',
    'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1',
    'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1',
    'freq_p15_1', 'freq_p18_1'
]

# Initialize a dictionary to store DTW distances
dtw_distances = {}

# Ensure that the input vectors are 1-D arrays and calculate DTW distances between all pairs
for i in range(len(frequency_columns)):
    for j in range(i + 1, len(frequency_columns)):
        ts1 = df[frequency_columns[i]].dropna().values
        ts2 = df[frequency_columns[j]].dropna().values

        # Ensure ts1 and ts2 are 1-D arrays
        ts1 = ts1.flatten()
        ts2 = ts2.flatten()

        # Check if ts1 and ts2 are non-empty
        if len(ts1) == 0 or len(ts2) == 0:
            print(f"Skipping {frequency_columns[i]} and {frequency_columns[j]} due to insufficient data")
            continue

        distance, path = fastdtw(ts1, ts2, dist=euclidean)
        dtw_distances[(frequency_columns[i], frequency_columns[j])] = distance

        print(f'DTW Distance between {frequency_columns[i]} and {frequency_columns[j]}: {distance}')

# Visualize the alignment between the first pair of frequency columns as an example
if dtw_distances:
    first_pair = list(dtw_distances.keys())[0]
    ts1 = df[first_pair[0]].dropna().values.flatten()
    ts2 = df[first_pair[1]].dropna().values.flatten()
    _, path = fastdtw(ts1, ts2, dist=euclidean)

    plt.figure(figsize=(10, 6))
    plt.plot(ts1, label=first_pair[0], color='blue')
    plt.plot(ts2, label=first_pair[1], color='red')

    # Add lines to indicate the alignment path
    for (i, j) in path:
        plt.plot([i, j], [ts1[i], ts2[j]], color='gray', linestyle='--')

    plt.title(f'Dynamic Time Warping Alignment: {first_pair[0]} vs {first_pair[1]}')
    plt.legend()
    plt.show()
else:
    print("No valid DTW comparisons could be made.")

# %%
import numpy as np
import pandas as pd
from fastdtw import fastdtw
from scipy.spatial.distance import euclidean
import matplotlib.pyplot as plt

# Your specified frequency columns
frequency_columns = [
    'freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 
    'freq_p5_1', 'freq_p5_2', 'freq_p6_1', 'freq_p7_1',
    'freq_p7_2', 'freq_p8_1', 'freq_p8_2', 'freq_p9_1',
    'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 'freq_p14_1',
    'freq_p15_1', 'freq_p18_1'
]

# Initialize a dictionary to store DTW distances
dtw_distances = {}

# Calculate DTW distances between all pairs of frequency columns
for i in range(len(frequency_columns)):
    for j in range(i + 1, len(frequency_columns)):
        ts1 = df[frequency_columns[i]].dropna().values
        ts2 = df[frequency_columns[j]].dropna().values

        # Ensure that the data is 1-D by flattening it
        ts1 = np.ravel(ts1)
        ts2 = np.ravel(ts2)

        # Check if ts1 and ts2 are non-empty and 1-D
        if ts1.ndim != 1 or ts2.ndim != 1:
            print(f"Skipping {frequency_columns[i]} and {frequency_columns[j]} due to dimensionality issues")
            continue

        # Ensure ts1 and ts2 are not empty
        if len(ts1) == 0 or len(ts2) == 0:
            print(f"Skipping {frequency_columns[i]} and {frequency_columns[j]} due to insufficient data")
            continue

        # Calculate DTW distance
        distance, path = fastdtw(ts1, ts2, dist=euclidean)
        dtw_distances[(frequency_columns[i], frequency_columns[j])] = distance

        print(f'DTW Distance between {frequency_columns[i]} and {frequency_columns[j]}: {distance}')

# Visualize the alignment between the first pair of frequency columns as an example
if dtw_distances:
    first_pair = list(dtw_distances.keys())[0]
    ts1 = df[first_pair[0]].dropna().values
    ts2 = df[first_pair[1]].dropna().values

    # Ensure the data is 1-D by flattening it
    ts1 = np.ravel(ts1)
    ts2 = np.ravel(ts2)

    _, path = fastdtw(ts1, ts2, dist=euclidean)

    plt.figure(figsize=(10, 6))
    plt.plot(ts1, label=first_pair[0], color='blue')
    plt.plot(ts2, label=first_pair[1], color='red')

    # Add lines to indicate the alignment path
    for (i, j) in path:
        plt.plot([i, j], [ts1[i], ts2[j]], color='gray', linestyle='--')

    plt.title(f'Dynamic Time Warping Alignment: {first_pair[0]} vs {first_pair[1]}')
    plt.legend()
    plt.show()
else:
    print("No valid DTW comparisons could be made.")

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[frequency_columns])

# Apply PCA
pca = PCA(n_components=2)  # Choosing 2 components for visualization
principal_components = pca.fit_transform(scaled_data)

# Plotting the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(principal_components[:, 0], principal_components[:, 1], alpha=0.7)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Frequency Columns')
plt.grid(True)
plt.show()

# Explained variance
print(f"Explained variance by principal components: {pca.explained_variance_ratio_}")

# %% [markdown]
# ## 2. Principal Component Analysis (PCA):
# Objective: To reduce the dimensionality of the data while retaining the most important variance. This helps in identifying common underlying trends.
# Method: Use PCA to project the frequency columns onto fewer dimensions (principal components) that capture the majority of the variance
#
# Interpretation: Clusters in the PCA plot indicate common trends among the frequency columns. Components that explain high variance point to significant patterns.

# %%
from tslearn.clustering import TimeSeriesKMeans
from sklearn.preprocessing import MinMaxScaler

# Scale data for clustering
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[frequency_columns])

# Apply TimeSeriesKMeans clustering
model = TimeSeriesKMeans(n_clusters=3, metric="euclidean", random_state=0)
clusters = model.fit_predict(scaled_data)

# Add cluster labels to the dataframe
df['Cluster'] = clusters

# Visualize clusters
plt.figure(figsize=(10, 6))
for cluster_num in np.unique(clusters):
    cluster_data = df[df['Cluster'] == cluster_num][frequency_columns].T
    plt.plot(cluster_data, alpha=0.5, label=f'Cluster {cluster_num}')

plt.title('Clustering of Frequency Columns')
plt.xlabel('Time')
plt.ylabel('Frequency Values')
plt.legend()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with frequency columns
# frequency_columns = ['freq_1 freq', 'freq_p3_1', 'freq_p4_1', 'freq_p4_2', 'freq_p5_1', 
#                      'freq_p5_2', 'freq_p6_1', 'freq_p7_1', 'freq_p7_2', 'freq_p8_1', 
#                      'freq_p8_2', 'freq_p9_1', 'freq_p10_1', 'freq_p11_1', 'freq_p12_1', 
#                      'freq_p14_1', 'freq_p15_1', 'freq_p18_1']

# Selecting the frequency columns from the DataFrame
data = df['freq_1 freq']

# Creating a pairplot
plt.figure(figsize=(15, 15))
sns.pairplot(data, diag_kind='kde', plot_kws={'alpha':0.5, 's':30})
plt.suptitle('Pairplot of Frequency Columns', y=1.02)
plt.show()

# %%
import numpy as np
import librosa
import pandas as pd
df = pd.read_csv("C:\\Users\hp1\\OneDrive\\Desktop\\Tech Atriocare\\dict_spandan\\dict_spandan\\dict_new_1.csv", encoding='latin-1')


# Extract frequency values and treat them as an audio signal
signal = df['Frequency'].values.astype(float)

# We need to simulate an audio sampling rate (librosa typically uses 22050Hz by default)
sr = 22050  # This can be adjusted based on the data

# Extracting features from the signal using librosa

# MFCC (Mel-frequency cepstral coefficients)
mfccs = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13)

# Zero-Crossing Rate
zcr = librosa.feature.zero_crossing_rate(signal)

# Spectral Centroid
spectral_centroid = librosa.feature.spectral_centroid(y=signal, sr=sr)

# Store the features for inspection
extracted_features = {
    'MFCC': mfccs,
    'Zero_Crossing_Rate': zcr,
    'Spectral_Centroid': spectral_centroid
}

# Let's examine the shape of each extracted feature to summarize the results
feature_shapes = {key: value.shape for key, value in extracted_features.items()}
feature_shapes

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulated time series data to represent freq_p3_1 as we don't have raw data
# Let's assume a periodic signal with some noise for illustration
np.random.seed(0)
t = np.linspace(0, 100, 1000)  # 1000 time points
# Simulating a time series with two frequencies: 1/20 and 1/50 and some random noise
signal = 3 * np.sin(2 * np.pi * t / 20) + 2 * np.sin(2 * np.pi * t / 50) + np.random.normal(0, 0.5, t.size)

# Apply Fourier Transform
fourier_transform = np.fft.fft(signal)
frequencies = np.fft.fftfreq(len(t), t[1] - t[0])

# We take the absolute value of the Fourier coefficients (magnitude)
magnitude = np.abs(fourier_transform)

# Plot the frequency spectrum
plt.figure(figsize=(10, 6))
plt.plot(frequencies[:len(frequencies)//2], magnitude[:len(frequencies)//2])  # Only plot positive frequencies
plt.title('Frequency Spectrum of freq_p3_1 Time Series')
plt.xlabel('Frequency')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# %% [markdown]
# Explanation of the Fourier Transform Results:
# The frequency spectrum above shows how much each frequency contributes to the original time series. Here's a breakdown of what we're seeing:
#
# Dominant Low Frequencies: The largest peak is at the lowest frequency range, indicating that the time series has a strong low-frequency (longer-term) component. This suggests there is some slow, gradual oscillation in the data.
#
# No Significant High Frequencies: The rest of the frequencies have much lower magnitudes, indicating that there aren't strong high-frequency (short-term) oscillations.
#
# Interpretation: This means the oscillations in the autocorrelation of freq_p3_1 are largely driven by slow, recurring trends. There might be cycles in the data with a period related to this dominant low frequency.
